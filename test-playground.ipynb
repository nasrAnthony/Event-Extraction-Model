# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
import torch
device = torch.device("cuda:0")

# %%
import random
import numpy as np
import torch

SEED = 42

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
import os
import copy
import math
import hashlib
from collections import Counter, defaultdict

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from transformers import AutoTokenizer, AutoModel
from sklearn.model_selection import KFold
from sklearn.metrics import f1_score, classification_report

# %%
# =============================================================================
# 0) Load data
# =============================================================================
# data_path = os.path.join(os.getcwd(), "..", "data", "cleaned", "full_data.csv")
# df = pd.read_csv(data_path)
df = pd.read_csv('/kaggle/input/datasets/yusufhilal/full-data/full_data.csv')

# =============================================================================
# 1) Label merge (APPLY IT)
# =============================================================================
LABEL_MERGE_MAP = {
    # keep
    "Other": "Other",

    # Name variants
    "Name": "Name",
    "NameLink": "Name",
    "NameLocation": "Name",

    # Date variants
    "Date": "Date",
    "DateTime": "Date",

    # Time variants
    "Time": "Time",
    "StartTime": "Time",
    "EndTime": "Time",
    "StartEndTime": "Time",
    "TimeLocation": "Time",

    "Location": "Location",

    "Description": "Description",
    "Desc": "Description",
    "Details": "Description",
}

def merge_labels(df, label_col="label", mapping=None, default_to_other=True):
    df = df.copy()
    mapping = mapping or {}

    def _map(x):
        x = str(x)
        if x in mapping:
            return mapping[x]
        return "Other" if default_to_other else x

    df[label_col] = df[label_col].map(_map)
    return df

df = merge_labels(df, "label", LABEL_MERGE_MAP)

# %%
df = df.sort_values(["source", "rendering_order"]).reset_index(drop=True)

df["in_event"] = df["event_id"].notna().astype(int)
df["start_event"] = 0

m = df["event_id"].notna()
first_idx = df.loc[m].groupby(["source", "event_id"], sort=False).head(1).index
df.loc[first_idx, "start_event"] = 1

# BIO: 0=O, 1=B, 2=I
# B = start of each event record
df["bio"] = 0
df.loc[df["in_event"].eq(1), "bio"] = 2
df.loc[df["start_event"].eq(1), "bio"] = 1

print("Pages:", df["source"].nunique())
print("Total nodes:", len(df))
print("Unique events:", df.loc[m].drop_duplicates(["source","event_id"]).shape[0])
print("Start positives:", int(df["start_event"].sum()))
print("Start rate:", float(df["start_event"].mean()))
print("Label counts:\n", df["label"].value_counts())
# Out:
# Pages: 15
# Total nodes: 2764
# Unique events: 177
# Start positives: 177
# Start rate: 0.06403762662807526
# Label counts:
#  label
# Other          1976
# Date            314
# Name            150
# Time            146
# Location        121
# Description      57
# Name: count, dtype: int64

# %%
# =============================================================================
# 3) Deduplicate identical pages BEFORE splitting (prevents leakage / misleading CV)
# =============================================================================
def page_fingerprint(g: pd.DataFrame) -> str:
    # Strong-ish fingerprint using ordered sequence of (tag, parent_tag, text_context)
    # You can add more columns if you want.
    parts = (
        g["tag"].astype(str).fillna("") + "\t" +
        g["parent_tag"].astype(str).fillna("") + "\t" +
        g["text_context"].astype(str).fillna("")
    ).tolist()
    s = "\n".join(parts)
    return hashlib.md5(s.encode("utf-8")).hexdigest()

fps = []
for src, g in df.groupby("source", sort=False):
    g = g.sort_values("rendering_order")
    fps.append((src, page_fingerprint(g)))

fp_df = pd.DataFrame(fps, columns=["source", "fp"])
dup_groups = fp_df.groupby("fp")["source"].apply(list)

# Keep the first source per fingerprint, drop others
keep_sources = []
drop_sources = []
for fp, sources in dup_groups.items():
    keep_sources.append(sources[0])
    if len(sources) > 1:
        drop_sources.extend(sources[1:])

if drop_sources:
    print("\n[DEDUP] Dropping duplicate pages:")
    for s in drop_sources:
        print("  -", s)

df = df[df["source"].isin(set(keep_sources))].copy()
df = df.sort_values(["source", "rendering_order"]).reset_index(drop=True)

print("\nAfter dedup:")
print("Pages:", df["source"].nunique())
print("Total nodes:", len(df))
# Out:
# [DEDUP] Dropping duplicate pages:
#   - members.sacac.org_pattern_labeled
#
# After dedup:
# Pages: 14
# Total nodes: 2491

# %%
print("CUDA available:", torch.cuda.is_available())
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

MODEL_NAME = "distilbert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

LABELS = sorted(df["label"].unique().tolist())
label2id = {l: i for i, l in enumerate(LABELS)}
id2label = {i: l for l, i in label2id.items()}
OTHER_ID = label2id["Other"]

TAG_VOCAB = {t: i for i, t in enumerate(sorted(df["tag"].astype(str).unique().tolist()))}
PARENT_TAG_VOCAB = {t: i for i, t in enumerate(sorted(df["parent_tag"].astype(str).unique().tolist()))}

STRUCT_COLS_NUM = [
    "depth","sibling_index","children_count","same_tag_sibling_count",
    "same_text_sibling_count","text_length","word_count",
    "letter_ratio","digit_ratio","whitespace_ratio","attribute_count"
]
STRUCT_COLS_BOOL = [
    "has_link","link_is_absolute","parent_has_link","is_leaf",
    "contains_date","contains_time","starts_with_digit","ends_with_digit",
    "has_class","has_id",
    "attr_has_word_name","attr_has_word_date","attr_has_word_time","attr_has_word_location","attr_has_word_link",
    "text_has_word_name","text_has_word_date","text_word_time","text_word_description","text_word_location"
]
# Out:
# CUDA available: True
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
all_sources = np.array(sorted(df["source"].unique()))
rng = np.random.default_rng(42)
rng.shuffle(all_sources)

TEST_N_PAGES = min(2, len(all_sources))
test_sources = set(all_sources[:TEST_N_PAGES])
cv_sources   = all_sources[TEST_N_PAGES:]

print("\nHoldout TEST pages:", len(test_sources), sorted(list(test_sources)))
test_df = df[df["source"].isin(test_sources)].copy()
# Out:
# Holdout TEST pages: 2 [np.str_('nacacnet.org_pattern_labeled'), np.str_('neacac_fall.net_pattern_labeled')]

# %%
# 6) Normalization: train-only stats per fold
# =============================================================================
def compute_num_stats(train_df: pd.DataFrame, cols):
    x = train_df[cols].fillna(0).values.astype("float32")
    mean = x.mean(axis=0)
    std = x.std(axis=0)
    std = np.where(std < 1e-6, 1.0, std).astype("float32")
    return mean.astype("float32"), std.astype("float32")

# =============================================================================
# 7) Dataset (stores BIO + in_event) and applies normalization
# =============================================================================
class PageDataset(Dataset):
    """
    Caches tokenization as Python lists.
    Applies numeric normalization using provided (mean, std).
    """
    def __init__(self, df, tokenizer, num_mean=None, num_std=None, max_tokens=64):
        self.pages = []
        self.max_tokens = max_tokens
        self.tokenizer = tokenizer

        if num_mean is None:
            num_mean = np.zeros((len(STRUCT_COLS_NUM),), dtype="float32")
        if num_std is None:
            num_std = np.ones((len(STRUCT_COLS_NUM),), dtype="float32")
        self.num_mean = num_mean
        self.num_std = num_std

        for src, g in df.groupby("source", sort=False):
            g = g.sort_values("rendering_order").reset_index(drop=True)

            texts = g["text_context"].astype(str).tolist()
            enc = tokenizer(
                texts,
                padding=False,
                truncation=True,
                max_length=max_tokens,
                return_attention_mask=True,
                return_tensors=None
            )

            num = g[STRUCT_COLS_NUM].fillna(0).values.astype("float32")
            num = (num - self.num_mean) / self.num_std

            page = {
                "input_ids": enc["input_ids"],
                "attention_mask": enc["attention_mask"],
                "field_y": [label2id[x] for x in g["label"].tolist()],
                "bio_y": g["bio"].astype(int).tolist(),          # 0/1/2
                "in_event_y": g["in_event"].astype(int).tolist(),# 0/1
                "tag_id": [TAG_VOCAB[str(x)] for x in g["tag"]],
                "parent_tag_id": [PARENT_TAG_VOCAB[str(x)] for x in g["parent_tag"]],
                "num_feats": num,
                "bool_feats": g[STRUCT_COLS_BOOL].astype(int).values.astype("float32"),
            }
            self.pages.append(page)

    def __len__(self):
        return len(self.pages)

    def __getitem__(self, idx):
        return self.pages[idx]

# %%
def collate_fn(batch):
    B = len(batch)
    max_nodes = max(len(x["input_ids"]) for x in batch)

    flat = []
    node_offsets = []
    node_mask = torch.zeros((B, max_nodes), dtype=torch.bool)

    start = 0
    for i, item in enumerate(batch):
        n = len(item["input_ids"])
        node_mask[i, :n] = True
        for j in range(n):
            flat.append({"input_ids": item["input_ids"][j], "attention_mask": item["attention_mask"][j]})
        end = start + n
        node_offsets.append((start, end))
        start = end

    enc = tokenizer.pad(flat, padding=True, return_tensors="pt")

    def pad_1d_list(list_of_lists, pad_value, dtype):
        out = torch.full((B, max_nodes), pad_value, dtype=dtype)
        for i, lst in enumerate(list_of_lists):
            n = len(lst)
            out[i, :n] = torch.tensor(lst, dtype=dtype)
        return out

    def pad_2d_array(list_of_arrays, feat_dim, pad_value=0.0, dtype=torch.float32):
        out = torch.full((B, max_nodes, feat_dim), pad_value, dtype=dtype)
        for i, arr in enumerate(list_of_arrays):
            n = arr.shape[0]
            out[i, :n, :] = torch.tensor(arr, dtype=dtype)
        return out

    field_y    = pad_1d_list([x["field_y"] for x in batch], pad_value=-100, dtype=torch.long)
    bio_y      = pad_1d_list([x["bio_y"] for x in batch],   pad_value=-100, dtype=torch.long)
    in_event_y = pad_1d_list([x["in_event_y"] for x in batch], pad_value=-100, dtype=torch.long)

    tag_id        = pad_1d_list([x["tag_id"] for x in batch], pad_value=0, dtype=torch.long)
    parent_tag_id = pad_1d_list([x["parent_tag_id"] for x in batch], pad_value=0, dtype=torch.long)

    num_feats  = pad_2d_array([x["num_feats"] for x in batch], feat_dim=len(STRUCT_COLS_NUM), pad_value=0.0)
    bool_feats = pad_2d_array([x["bool_feats"] for x in batch], feat_dim=len(STRUCT_COLS_BOOL), pad_value=0.0)

    return {
        "enc": enc,
        "node_offsets": node_offsets,
        "node_mask": node_mask,
        "field_y": field_y,
        "bio_y": bio_y,
        "in_event_y": in_event_y,
        "tag_id": tag_id,
        "parent_tag_id": parent_tag_id,
        "num_feats": num_feats,
        "bool_feats": bool_feats,
    }

# %%
class DOMAwareEventExtractor(nn.Module):
    def __init__(
        self,
        text_model_name: str,
        tag_vocab_size: int,
        parent_tag_vocab_size: int,
        d_model: int = 128,
        nhead: int = 4,
        num_layers: int = 1,
        dropout: float = 0.2
    ):
        super().__init__()
        self.text_encoder = AutoModel.from_pretrained(text_model_name)
        text_dim = self.text_encoder.config.hidden_size

        self.text_proj = nn.Linear(text_dim, d_model)

        self.tag_emb = nn.Embedding(tag_vocab_size, d_model)
        self.parent_tag_emb = nn.Embedding(parent_tag_vocab_size, d_model)

        self.num_proj = nn.Linear(len(STRUCT_COLS_NUM), d_model)
        self.bool_proj = nn.Linear(len(STRUCT_COLS_BOOL), d_model)

        self.layernorm = nn.LayerNorm(d_model)

        enc_layer = nn.TransformerEncoderLayer(
            d_model=d_model, nhead=nhead, dropout=dropout, batch_first=True
        )
        self.node_encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)

        # self.field_head = nn.Linear(d_model, num_field_labels)
        self.bio_head = nn.Linear(d_model, 3)       # O/B/I
        # self.in_event_head = nn.Linear(d_model, 1)  # binary

    def forward(self, enc, node_offsets, node_mask, tag_id, parent_tag_id, num_feats, bool_feats):
        out = self.text_encoder(**enc)
        cls = out.last_hidden_state[:, 0, :]     # [total_nodes, text_dim]
        node_text = self.text_proj(cls)          # [total_nodes, d_model]

        B, max_nodes = node_mask.shape
        packed = node_text.new_zeros((B, max_nodes, node_text.shape[-1]))
        for i, (s, e) in enumerate(node_offsets):
            packed[i, : (e - s), :] = node_text[s:e]

        x = (
            packed
            + self.tag_emb(tag_id)
            + self.parent_tag_emb(parent_tag_id)
            + self.num_proj(num_feats)
            + self.bool_proj(bool_feats)
        )
        x = self.layernorm(x)

        key_padding_mask = ~node_mask
        x = self.node_encoder(x, src_key_padding_mask=key_padding_mask)

        # field_logits = self.field_head(x)                  # [B, N, C]
        bio_logits   = self.bio_head(x)                    # [B, N, 3]
        # in_event_logits = self.in_event_head(x).squeeze(-1)# [B, N]
        return bio_logits

# %%
# def make_losses_for_train_df(
#     train_df,
#     LABELS,
#     device,
#     other_scale=0.05,
#     weight_cap=50.0
# ):
#     # ---- Field weights ----
#     label_counts = Counter(train_df["label"].tolist())
#     total = sum(label_counts.values())
#     weights = []
#     for label in LABELS:
#         c = label_counts.get(label, 1)
#         weights.append(total / c)
#     weights = torch.tensor(weights, dtype=torch.float32, device=device)
#     weights = torch.clamp(weights, max=weight_cap)
#     if "Other" in LABELS:
#         weights[LABELS.index("Other")] *= other_scale

#     field_loss_fn = nn.CrossEntropyLoss(weight=weights, ignore_index=-100)

#     # ---- BIO weights ----
#     bio_counts = Counter(train_df["bio"].tolist())
#     # bio labels are 0/1/2, but ensure all exist
#     bio_total = sum(bio_counts.get(i, 0) for i in [0,1,2])
#     bio_w = []
#     for i in [0,1,2]:
#         c = bio_counts.get(i, 1)
#         bio_w.append(bio_total / c)
#     bio_w = torch.tensor(bio_w, dtype=torch.float32, device=device)
#     bio_w = torch.clamp(bio_w, max=weight_cap)
#     bio_loss_fn = nn.CrossEntropyLoss(weight=bio_w, ignore_index=-100)

#     # ---- in_event pos_weight ----
#     pos = float(train_df["in_event"].sum())
#     neg = float(len(train_df) - pos)
#     pos_weight = torch.tensor([neg / (pos + 1e-6)], dtype=torch.float32, device=device)
#     in_event_loss_fn = nn.BCEWithLogitsLoss(pos_weight=pos_weight)

#     return field_loss_fn, bio_loss_fn, in_event_loss_fn

def make_bio_loss(device):
    return torch.nn.CrossEntropyLoss(ignore_index=-100).to(device)

# %%
def pick_starts_from_probs(probs, threshold=0.5, nms_k=1, min_gap=2):
    """
    probs: 1D numpy array of prob(B) per node (valid nodes only)
    Returns sorted list of predicted start indices (within valid-node indexing)
    Steps:
      - threshold
      - local maxima (nms_k neighborhood)
      - greedy keep with min_gap
    """
    probs = np.asarray(probs)
    N = probs.shape[0]
    if N == 0:
        return []

    # Candidates above threshold
    cand = np.where(probs >= threshold)[0]
    if cand.size == 0:
        return []

    # Local maxima within +/- nms_k
    if nms_k > 0:
        keep = []
        for i in cand:
            lo = max(0, i - nms_k)
            hi = min(N, i + nms_k + 1)
            if probs[i] >= probs[lo:hi].max() - 1e-12:
                keep.append(i)
        cand = np.array(keep, dtype=int)
        if cand.size == 0:
            return []

    # Greedy by prob descending, enforce min_gap
    order = cand[np.argsort(-probs[cand])]
    chosen = []
    for idx in order:
        if all(abs(idx - j) > min_gap for j in chosen):
            chosen.append(int(idx))
    return sorted(chosen)

def start_prf_with_tolerance(true_starts, pred_starts, tol=1):
    """
    true_starts, pred_starts: sorted lists of indices
    tolerance: pred counts as TP if within +/- tol of an unmatched true
    """
    true_starts = list(true_starts)
    pred_starts = list(pred_starts)

    matched_true = set()
    tp = 0
    for p in pred_starts:
        best = None
        best_dist = None
        for ti, t in enumerate(true_starts):
            if ti in matched_true:
                continue
            d = abs(p - t)
            if d <= tol and (best_dist is None or d < best_dist):
                best = ti
                best_dist = d
        if best is not None:
            matched_true.add(best)
            tp += 1

    fp = len(pred_starts) - tp
    fn = len(true_starts) - tp

    prec = tp / (tp + fp + 1e-9)
    rec  = tp / (tp + fn + 1e-9)
    f1   = 2 * prec * rec / (prec + rec + 1e-9)
    return prec, rec, f1

# %%
@torch.no_grad()
def collect_page_probs_and_truth(loader, model, device):
    model.eval()
    pages = []

    with torch.no_grad():
        for batch in loader:

            enc = {k: v.to(device) for k, v in batch["enc"].items()}
            node_mask = batch["node_mask"].to(device)
            tag_id = batch["tag_id"].to(device)
            parent_tag_id = batch["parent_tag_id"].to(device)
            num_feats = batch["num_feats"].to(device)
            bool_feats = batch["bool_feats"].to(device)

            bio_logits = model(
                enc=enc,
                node_offsets=batch["node_offsets"],
                node_mask=node_mask,
                tag_id=tag_id,
                parent_tag_id=parent_tag_id,
                num_feats=num_feats,
                bool_feats=bool_feats,
            )

            probs = torch.softmax(bio_logits, dim=-1)  # [B, N, 3]

            # Remove batch dimension
            probs = probs[0]
            node_mask = node_mask[0]

            # Keep only valid nodes
            probs_valid = probs[node_mask]              # [N_valid, 3]
            true_valid = batch["boundary_y"][0][node_mask]

            # Convert to numpy
            probs_valid = probs_valid.detach().cpu().numpy()
            true_valid = true_valid.detach().cpu().numpy()

            # IMPORTANT:
            # We return BOTH:
            #   - full BIO probabilities
            #   - prob_B (for backward compatibility)
            #   - true_start
            prob_B = probs_valid[:, 1]

            pages.append((probs_valid, prob_B, true_valid))

    return pages

@torch.no_grad()
def find_best_threshold_peak(
    loader,
    model,
    device,
    thresholds=None,
    nms_k=1,
    min_gap=2,
    tol=1
):
    if thresholds is None:
        thresholds = np.linspace(0.05, 0.95, 19)

    pages = collect_page_probs_and_truth(loader, model, device)
    if len(pages) == 0:
        return 0.5, 0.0

    best_th = 0.5
    best_f1 = -1.0

    for th in thresholds:
        ps = []
        rs = []
        fs = []
        # Micro over pages by summing TP/FP/FN (more stable than averaging F1)
        TP = FP = FN = 0
        for prob_B, true_start in pages:
            true_idx = np.where(true_start == 1)[0].tolist()
            pred_idx = pick_starts_from_probs(prob_B, threshold=th, nms_k=nms_k, min_gap=min_gap)
            p, r, f = start_prf_with_tolerance(true_idx, pred_idx, tol=tol)
            # Convert per-page p/r/f to counts for micro:
            # We can directly derive counts:
            # - tp from tolerance matching (recompute counts)
            # We'll approximate by converting:
            # tp = p*(tp+fp) etc is messy. Let's recompute counts exactly:
            # Do exact matching:
            matched_true = set()
            tp = 0
            for pr in pred_idx:
                best = None
                best_dist = None
                for ti, t in enumerate(true_idx):
                    if ti in matched_true:
                        continue
                    d = abs(pr - t)
                    if d <= tol and (best_dist is None or d < best_dist):
                        best = ti
                        best_dist = d
                if best is not None:
                    matched_true.add(best)
                    tp += 1
            fp = len(pred_idx) - tp
            fn = len(true_idx) - tp

            TP += tp
            FP += fp
            FN += fn

        prec = TP / (TP + FP + 1e-9)
        rec  = TP / (TP + FN + 1e-9)
        f1   = 2 * prec * rec / (prec + rec + 1e-9)

        if f1 > best_f1:
            best_f1 = f1
            best_th = float(th)

    return best_th, float(best_f1)

# %%
@torch.no_grad()
def boundary_metrics_peak(loader, model, device, threshold, nms_k=1, min_gap=2, tol=1):
    pages = collect_page_probs_and_truth(loader, model, device)
    if len(pages) == 0:
        return 0.0, 0.0, 0.0

    TP = FP = FN = 0
    for prob_B, true_start in pages:
        true_idx = np.where(true_start == 1)[0].tolist()
        pred_idx = pick_starts_from_probs(prob_B, threshold=threshold, nms_k=nms_k, min_gap=min_gap)

        matched_true = set()
        tp = 0
        for pr in pred_idx:
            best = None
            best_dist = None
            for ti, t in enumerate(true_idx):
                if ti in matched_true:
                    continue
                d = abs(pr - t)
                if d <= tol and (best_dist is None or d < best_dist):
                    best = ti
                    best_dist = d
            if best is not None:
                matched_true.add(best)
                tp += 1
        fp = len(pred_idx) - tp
        fn = len(true_idx) - tp

        TP += tp
        FP += fp
        FN += fn

    prec = TP / (TP + FP + 1e-9)
    rec  = TP / (TP + FN + 1e-9)
    f1   = 2 * prec * rec / (prec + rec + 1e-9)
    return float(prec), float(rec), float(f1)

# =============================================================================
# 12) Field metrics: ignore Other, ignore padding. (Optionally restrict to in_event)
# =============================================================================
# @torch.no_grad()
# def field_metrics_fast(loader, model, device, label2id, average="micro", restrict_to_true_in_event=False):
#     model.eval()
#     yt, yp = [], []
#     OTHER_ID = label2id["Other"]

#     for batch in loader:
#         enc = {k: v.to(device, non_blocking=True) for k, v in batch["enc"].items()}
#         node_mask = batch["node_mask"].to(device).bool()
#         field_y = batch["field_y"].to(device)
#         in_event_y = batch["in_event_y"].to(device)

#         field_logits, bio_logits, in_event_logits = model(
#             enc=enc,
#             node_offsets=batch["node_offsets"],
#             node_mask=node_mask,
#             tag_id=batch["tag_id"].to(device),
#             parent_tag_id=batch["parent_tag_id"].to(device),
#             num_feats=batch["num_feats"].to(device),
#             bool_feats=batch["bool_feats"].to(device),
#         )
#         pred = torch.argmax(field_logits, dim=-1)

#         valid = node_mask & (field_y != -100) & (field_y != OTHER_ID)
#         if restrict_to_true_in_event:
#             valid = valid & (in_event_y == 1)

#         yt.extend(field_y[valid].detach().cpu().tolist())
#         yp.extend(pred[valid].detach().cpu().tolist())

#     if len(yt) == 0:
#         return 0.0
#     return float(f1_score(yt, yp, average=average, zero_division=0))

# %%
# 13) Loaders (pass num stats)
# =============================================================================
def make_loaders(train_df, val_df, num_mean, num_std, batch_size=2, max_tokens=64):
    train_dataset = PageDataset(train_df, tokenizer=tokenizer, num_mean=num_mean, num_std=num_std, max_tokens=max_tokens)
    val_dataset   = PageDataset(val_df, tokenizer=tokenizer, num_mean=num_mean, num_std=num_std, max_tokens=max_tokens)

    train_loader = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        collate_fn=collate_fn,
        num_workers=0,
        pin_memory=False,
        persistent_workers=False
    )
    val_loader = DataLoader(
        val_dataset,
        batch_size=batch_size,
        shuffle=False,
        collate_fn=collate_fn,
        num_workers=0,
        pin_memory=False,
        persistent_workers=False
    )
    return train_loader, val_loader

# %%
# 14) Optim: freeze warmup + differential LRs
# =============================================================================
def init_model_and_optim(lr_bert=5e-6, lr_other=1e-4, weight_decay=0.01):
    model = DOMAwareEventExtractor(
        text_model_name=MODEL_NAME,
        tag_vocab_size=len(TAG_VOCAB),
        parent_tag_vocab_size=len(PARENT_TAG_VOCAB),
        d_model=128,
        nhead=4,
        num_layers=2,
        dropout = 0.3
    ).to(device)

    bert_params = []
    other_params = []
    for n, p in model.named_parameters():
        if n.startswith("text_encoder."):
            bert_params.append(p)
        else:
            other_params.append(p)

    optimizer = torch.optim.AdamW(
        [
            {"params": bert_params, "lr": lr_bert, "weight_decay": weight_decay},
            {"params": other_params, "lr": lr_other, "weight_decay": weight_decay},
        ]
    )
    return model, optimizer

def set_bert_trainable(model, trainable: bool):
    for p in model.text_encoder.parameters():
        p.requires_grad = trainable

# =============================================================================
# 15) Train / Eval epoch (losses include Other; BIO + in_event auxiliary)
# =============================================================================
def run_epoch(
    model,
    optimizer,
    loader,
    bio_loss_fn,
    training=True
):
    model.train() if training else model.eval()
    total_loss = 0.0

    for batch in loader:
        enc = {k: v.to(device, non_blocking=True) for k, v in batch["enc"].items()}
        node_mask = batch["node_mask"].to(device).bool()

        # field_y = batch["field_y"].to(device)
        bio_y   = batch["bio_y"].to(device)
        # in_event_y = batch["in_event_y"].to(device)

        with torch.set_grad_enabled(training):
            bio_logits= model(
                enc=enc,
                node_offsets=batch["node_offsets"],
                node_mask=node_mask,
                tag_id=batch["tag_id"].to(device),
                parent_tag_id=batch["parent_tag_id"].to(device),
                num_feats=batch["num_feats"].to(device),
                bool_feats=batch["bool_feats"].to(device),
            )


            # BIO loss: excluding padding
            # bio_mask = node_mask & (bio_y != -100)
            bio_loss = bio_loss_fn(bio_logits.view(-1, 3), bio_y.view(-1))
            loss = bio_loss

            if training:
                optimizer.zero_grad(set_to_none=True)
                loss.backward()
                torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
                optimizer.step()

        total_loss += loss.detach().item()

    return total_loss / max(1, len(loader))

# %%
# 16) Cross-val by source
# =============================================================================
N_SPLITS = min(5, len(cv_sources))
kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=42)

# Peak-decoding hyperparams (tune these a bit if needed)
NMS_K = 1
MIN_GAP = 2
TOL = 1

EPOCHS = 20
FREEZE_EPOCHS = 5  # freeze DistilBERT for first few epochs

cv_results = []

for fold, (tr_idx, va_idx) in enumerate(kf.split(cv_sources), start=1):
    # if fold != 1:
    #     break
    torch.cuda.empty_cache()
    fold_train_sources = set(cv_sources[tr_idx])
    fold_val_sources   = set(cv_sources[va_idx])

    fold_train_df = df[df["source"].isin(fold_train_sources)].copy()
    fold_val_df   = df[df["source"].isin(fold_val_sources)].copy()

    num_mean, num_std = compute_num_stats(fold_train_df, STRUCT_COLS_NUM)

    bio_loss_fn = make_bio_loss(device)

    print(f"\n===== Fold {fold}/{N_SPLITS} =====")
    print("Train pages:", fold_train_df["source"].nunique(), "Val pages:", fold_val_df["source"].nunique())

    train_loader, val_loader = make_loaders(
        fold_train_df, fold_val_df,
        num_mean=num_mean, num_std=num_std,
        batch_size=2, max_tokens=64
    )

    model, optimizer = init_model_and_optim(lr_bert=5e-6, lr_other=1e-4)

    best = {"f1": -1.0, "th": 0.5, "state": None}

    # Freeze BERT initially
    set_bert_trainable(model, False)

    for epoch in range(EPOCHS):
        if epoch == FREEZE_EPOCHS:
            set_bert_trainable(model, True)

        tr_loss = run_epoch(
            model, optimizer, train_loader,
            bio_loss_fn,
            training=True
        )
        va_loss = run_epoch(
            model, optimizer, val_loader,
            bio_loss_fn,
            training=False
        )

        th, f1 = find_best_threshold_peak(
            val_loader, model, device,
            thresholds=np.linspace(0.05, 0.95, 19),
            nms_k=NMS_K, min_gap=MIN_GAP, tol=TOL
        )

        if f1 > best["f1"]:
            best["f1"] = f1
            best["th"] = th
            # best["state"] = copy.deepcopy(model.state_dict())
            best["state"] = {k: v.cpu() for k, v in model.state_dict().items()}

        if (epoch + 1) % 5 == 0:
            print(f"Epoch {epoch+1:02d} | tr_loss={tr_loss:.4f} va_loss={va_loss:.4f} best_startF1={best['f1']:.4f} best_th={best['th']:.2f}")

    model.load_state_dict(best["state"])

    bp, br, bf1 = boundary_metrics_peak(val_loader, model, device, threshold=best["th"], nms_k=NMS_K, min_gap=MIN_GAP, tol=TOL)

    # # Field metrics: ignore Other. You can choose restrict_to_true_in_event=True if you prefer.
    # field_micro_f1 = field_metrics_fast(val_loader, model, device, label2id=label2id, average="micro", restrict_to_true_in_event=False)
    # field_macro_f1 = field_metrics_fast(val_loader, model, device, label2id=label2id, average="macro", restrict_to_true_in_event=False)

    print(
        f"Fold {fold} | START (peak-based): P={bp:.4f} R={br:.4f} F1={bf1:.4f} (th={best['th']:.2f}, nms_k={NMS_K}, min_gap={MIN_GAP}, tol=±{TOL})"
        # f" | field: microF1={field_micro_f1:.4f} macroF1={field_macro_f1:.4f}"
    )

    cv_results.append({
        "fold": fold,
        "bp": bp, "br": br, "bf1": bf1, "th": best["th"],
        # "field_micro_f1": field_micro_f1,
        # "field_macro_f1": field_macro_f1,
        "num_mean": num_mean,
        "num_std": num_std,
    })

    del model
    del optimizer
    torch.cuda.empty_cache()

print("\n===== CV Summary =====")
mean_bf1 = float(np.mean([x["bf1"] for x in cv_results])) if cv_results else 0.0
mean_bp  = float(np.mean([x["bp"]  for x in cv_results])) if cv_results else 0.0
mean_br  = float(np.mean([x["br"]  for x in cv_results])) if cv_results else 0.0
mean_th  = float(np.mean([x["th"]  for x in cv_results])) if cv_results else 0.5
# mean_field_micro = float(np.mean([x["field_micro_f1"] for x in cv_results])) if cv_results else 0.0
# mean_field_macro = float(np.mean([x["field_macro_f1"] for x in cv_results])) if cv_results else 0.0

print(f"START (peak) Mean F1: {mean_bf1:.4f}")
print(f"START (peak) Mean P : {mean_bp:.4f}")
print(f"START (peak) Mean R : {mean_br:.4f}")
print(f"START (peak) Mean th: {mean_th:.4f}")
# print(f"Field Mean micro-F1 (ignore Other): {mean_field_micro:.4f}")
# print(f"Field Mean macro-F1 (ignore Other): {mean_field_macro:.4f}")

best_th_cv = mean_th
print("Using CV-avg threshold:", best_th_cv)
# Out:
# ===== Fold 1/5 =====
# Train pages: 9 Val pages: 3
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/100 [00:00<?, ?it/s]
# DistilBertModel LOAD REPORT from: distilbert-base-uncased
# Key                     | Status     |  |
# ------------------------+------------+--+-
# vocab_layer_norm.weight | UNEXPECTED |  |
# vocab_transform.weight  | UNEXPECTED |  |
# vocab_transform.bias    | UNEXPECTED |  |
# vocab_projector.bias    | UNEXPECTED |  |
# vocab_layer_norm.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py:515: UserWarning: The PyTorch API of nested tensors is in prototype stage and will change in the near future. We recommend specifying layout=torch.jagged when constructing a nested tensor, as this layout receives active development, has better operator coverage, and works with torch.compile. (Triggered internally at /pytorch/aten/src/ATen/NestedTensorImpl.cpp:178.)
#   output = torch._nested_tensor_from_mask(
# Epoch 05 | tr_loss=0.5141 va_loss=0.5608 best_startF1=0.7273 best_th=0.05
# Epoch 10 | tr_loss=0.2786 va_loss=0.4884 best_startF1=0.7273 best_th=0.05
# Epoch 15 | tr_loss=0.1379 va_loss=0.4927 best_startF1=0.8000 best_th=0.10
# Epoch 20 | tr_loss=0.0697 va_loss=0.5283 best_startF1=0.8462 best_th=0.10
# Fold 1 | START (peak-based): P=0.8462 R=0.8462 F1=0.8462 (th=0.10, nms_k=1, min_gap=2, tol=±1)
#
# ===== Fold 2/5 =====
# Train pages: 9 Val pages: 3
# Loading weights:   0%|          | 0/100 [00:00<?, ?it/s]
# DistilBertModel LOAD REPORT from: distilbert-base-uncased
# Key                     | Status     |  |
# ------------------------+------------+--+-
# vocab_layer_norm.weight | UNEXPECTED |  |
# vocab_transform.weight  | UNEXPECTED |  |
# vocab_transform.bias    | UNEXPECTED |  |
# vocab_projector.bias    | UNEXPECTED |  |
# vocab_layer_norm.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Epoch 05 | tr_loss=0.5582 va_loss=0.6358 best_startF1=0.5333 best_th=0.05
# Epoch 10 | tr_loss=0.3005 va_loss=0.5711 best_startF1=0.5333 best_th=0.05
# Epoch 15 | tr_loss=0.1701 va_loss=0.5173 best_startF1=0.6087 best_th=0.05
# Epoch 20 | tr_loss=0.1001 va_loss=0.5354 best_startF1=0.7368 best_th=0.05
# Fold 2 | START (peak-based): P=0.7778 R=0.7000 F1=0.7368 (th=0.05, nms_k=1, min_gap=2, tol=±1)
#
# ===== Fold 3/5 =====
# Train pages: 10 Val pages: 2
# Loading weights:   0%|          | 0/100 [00:00<?, ?it/s]
# DistilBertModel LOAD REPORT from: distilbert-base-uncased
# Key                     | Status     |  |
# ------------------------+------------+--+-
# vocab_layer_norm.weight | UNEXPECTED |  |
# vocab_transform.weight  | UNEXPECTED |  |
# vocab_transform.bias    | UNEXPECTED |  |
# vocab_projector.bias    | UNEXPECTED |  |
# vocab_layer_norm.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Epoch 05 | tr_loss=0.5246 va_loss=0.3376 best_startF1=0.4000 best_th=0.15
# Epoch 10 | tr_loss=0.3180 va_loss=0.2877 best_startF1=0.7143 best_th=0.20
# Epoch 15 | tr_loss=0.1593 va_loss=0.2759 best_startF1=0.8571 best_th=0.25
# Epoch 20 | tr_loss=0.0802 va_loss=0.3045 best_startF1=0.8571 best_th=0.25
# Fold 3 | START (peak-based): P=1.0000 R=0.7500 F1=0.8571 (th=0.25, nms_k=1, min_gap=2, tol=±1)
#
# ===== Fold 4/5 =====
# Train pages: 10 Val pages: 2
# Loading weights:   0%|          | 0/100 [00:00<?, ?it/s]
# DistilBertModel LOAD REPORT from: distilbert-base-uncased
# Key                     | Status     |  |
# ------------------------+------------+--+-
# vocab_layer_norm.weight | UNEXPECTED |  |
# vocab_transform.weight  | UNEXPECTED |  |
# vocab_transform.bias    | UNEXPECTED |  |
# vocab_projector.bias    | UNEXPECTED |  |
# vocab_layer_norm.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Epoch 05 | tr_loss=0.3926 va_loss=1.4290 best_startF1=0.0000 best_th=0.05
# Epoch 10 | tr_loss=0.2199 va_loss=1.7326 best_startF1=0.7000 best_th=0.05
# Epoch 15 | tr_loss=0.1271 va_loss=1.9534 best_startF1=0.7000 best_th=0.05
# Epoch 20 | tr_loss=0.0631 va_loss=2.2112 best_startF1=0.7000 best_th=0.05
# Fold 4 | START (peak-based): P=0.6087 R=0.8235 F1=0.7000 (th=0.05, nms_k=1, min_gap=2, tol=±1)
#
# ===== Fold 5/5 =====
# Train pages: 10 Val pages: 2
# Loading weights:   0%|          | 0/100 [00:00<?, ?it/s]
# DistilBertModel LOAD REPORT from: distilbert-base-uncased
# Key                     | Status     |  |
# ------------------------+------------+--+-
# vocab_layer_norm.weight | UNEXPECTED |  |
# vocab_transform.weight  | UNEXPECTED |  |
# vocab_transform.bias    | UNEXPECTED |  |
# vocab_projector.bias    | UNEXPECTED |  |
# vocab_layer_norm.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Epoch 05 | tr_loss=0.5816 va_loss=0.7293 best_startF1=0.7742 best_th=0.10
# Epoch 10 | tr_loss=0.2974 va_loss=0.6234 best_startF1=0.8615 best_th=0.20
# Epoch 15 | tr_loss=0.1391 va_loss=0.6888 best_startF1=0.8615 best_th=0.20
# Epoch 20 | tr_loss=0.0634 va_loss=0.8297 best_startF1=0.8788 best_th=0.15
# Fold 5 | START (peak-based): P=0.8788 R=0.8788 F1=0.8788 (th=0.15, nms_k=1, min_gap=2, tol=±1)
#
# ===== CV Summary =====
# START (peak) Mean F1: 0.8038
# START (peak) Mean P : 0.8223
# START (peak) Mean R : 0.7997
# START (peak) Mean th: 0.1200
# Using CV-avg threshold: 0.12
#
# Training FINAL boundary model on full CV data...
# Loading weights:   0%|          | 0/100 [00:00<?, ?it/s]
# DistilBertModel LOAD REPORT from: distilbert-base-uncased
# Key                     | Status     |  |
# ------------------------+------------+--+-
# vocab_layer_norm.weight | UNEXPECTED |  |
# vocab_transform.weight  | UNEXPECTED |  |
# vocab_transform.bias    | UNEXPECTED |  |
# vocab_projector.bias    | UNEXPECTED |  |
# vocab_layer_norm.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Epoch 05 | tr_loss=0.4993
# Epoch 10 | tr_loss=0.2787
# Epoch 15 | tr_loss=0.1202
# Epoch 20 | tr_loss=0.0729
# Final boundary model ready.

# %%
# ==========================================================
# Train FINAL boundary model on all CV data
# ==========================================================

print("\nTraining FINAL boundary model on full CV data...")

final_train_df = df[df["source"].isin(cv_sources)].copy()

num_mean, num_std = compute_num_stats(final_train_df, STRUCT_COLS_NUM)

train_loader, _ = make_loaders(
    final_train_df,
    final_train_df,   # dummy val (not used)
    num_mean=num_mean,
    num_std=num_std,
    batch_size=2,
    max_tokens=64
)

model, optimizer = init_model_and_optim(lr_bert=5e-6, lr_other=1e-4)
bio_loss_fn = make_bio_loss(device)

set_bert_trainable(model, False)

for epoch in range(EPOCHS):

    if epoch == FREEZE_EPOCHS:
        set_bert_trainable(model, True)

    tr_loss = run_epoch(
        model,
        optimizer,
        train_loader,
        bio_loss_fn,
        training=True
    )

    if (epoch+1) % 5 == 0:
        print(f"Epoch {epoch+1:02d} | tr_loss={tr_loss:.4f}")

print("Final boundary model ready.")

# %%
# Gradient Boost Field Classifier (Hybrid)
# Uses structural + tag features + text TF-IDF
# Ignores "Other"
# =============================================================================

from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import KFold
from sklearn.metrics import f1_score, confusion_matrix
from sklearn.preprocessing import LabelEncoder
from scipy.sparse import hstack, csr_matrix

print("\n========== Gradient Boost Field Classifier ==========")

# ------------------------------------------------------------------
# 1) Prepare data (ignore Other)
# ------------------------------------------------------------------
field_df = df[df["label"] != "Other"].copy()
print("Remaining samples:", len(field_df))
print("Label distribution:\n", field_df["label"].value_counts())

# Encode labels
le = LabelEncoder()
y = le.fit_transform(field_df["label"])
print("Encoded labels:", list(le.classes_))

# ------------------------------------------------------------------
# 2) Text features (TF-IDF)
# ------------------------------------------------------------------
tfidf = TfidfVectorizer(
    max_features=300,
    ngram_range=(1,2),
    stop_words="english"
)
X_text = tfidf.fit_transform(field_df["text_context"].astype(str))

# ------------------------------------------------------------------
# 3) Structural features
# ------------------------------------------------------------------
num_feats = field_df[STRUCT_COLS_NUM].fillna(0).values
bool_feats = field_df[STRUCT_COLS_BOOL].fillna(0).values

tag_feats = field_df["tag"].astype(str)
parent_feats = field_df["parent_tag"].astype(str)

# One-hot encoding
tag_onehot = pd.get_dummies(tag_feats)
parent_onehot = pd.get_dummies(parent_feats)

# SAVE COLUMN STRUCTURE FOR INFERENCE
TAG_COLUMNS = tag_onehot.columns.tolist()
PARENT_COLUMNS = parent_onehot.columns.tolist()

X_struct = np.hstack([
    num_feats,
    bool_feats,
    tag_onehot.values,
    parent_onehot.values
])

X_struct = csr_matrix(X_struct)

# ------------------------------------------------------------------
# 4) Combine features
# ------------------------------------------------------------------
X = hstack([X_text, X_struct]).tocsr()
print("Feature matrix shape:", X.shape)

# ------------------------------------------------------------------
# 5) Cross-validation
# ------------------------------------------------------------------
kf = KFold(n_splits=5, shuffle=True, random_state=42)

micro_scores = []
macro_scores = []

for fold, (train_idx, val_idx) in enumerate(kf.split(X), 1):

    X_train, X_val = X[train_idx], X[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    clf = GradientBoostingClassifier(
        n_estimators=200,
        learning_rate=0.05,
        max_depth=3,
        random_state=42
    )

    clf.fit(X_train.toarray(), y_train)
    y_pred = clf.predict(X_val.toarray())

    micro = f1_score(y_val, y_pred, average="micro")
    macro = f1_score(y_val, y_pred, average="macro")

    micro_scores.append(micro)
    macro_scores.append(macro)

    correct = (y_pred == y_val).sum()
    total = len(y_val)

    print(f"\nFold {fold}")
    print(f"Correct: {correct} / {total}")
    print(f"microF1={micro:.4f} macroF1={macro:.4f}")
    print("Confusion matrix:\n", confusion_matrix(y_val, y_pred))

print("\n===== Gradient Boost CV Summary =====")
print("Mean micro-F1:", np.mean(micro_scores))
print("Mean macro-F1:", np.mean(macro_scores))
# Out:
# ========== Gradient Boost Field Classifier ==========
# Remaining samples: 608
# Label distribution:
#  label
# Date           224
# Location       121
# Name           120
# Time           116
# Description     27
# Name: count, dtype: int64
# Encoded labels: ['Date', 'Description', 'Location', 'Name', 'Time']
# Feature matrix shape: (608, 354)
#
# Fold 1
# Correct: 116 / 122
# microF1=0.9508 macroF1=0.9329
# Confusion matrix:
#  [[53  0  0  0  0]
#  [ 0  6  1  0  0]
#  [ 0  0 17  2  1]
#  [ 0  0  2 23  0]
#  [ 0  0  0  0 17]]
#
# Fold 2
# Correct: 118 / 122
# microF1=0.9672 macroF1=0.9681
# Confusion matrix:
#  [[40  0  0  0  0]
#  [ 0  6  0  0  0]
#  [ 0  0 24  0  0]
#  [ 0  0  1 27  1]
#  [ 0  0  1  1 21]]
#
# Fold 3
# Correct: 118 / 122
# microF1=0.9672 macroF1=0.9692
# Confusion matrix:
#  [[45  0  1  0  0]
#  [ 0  4  0  0  0]
#  [ 0  0 33  0  0]
#  [ 0  0  2 15  0]
#  [ 0  0  1  0 21]]
#
# Fold 4
# Correct: 114 / 121
# microF1=0.9421 macroF1=0.9228
# Confusion matrix:
#  [[41  0  0  0  0]
#  [ 0  3  1  0  0]
#  [ 0  0 27  0  0]
#  [ 0  0  5 21  0]
#  [ 0  0  1  0 22]]
#
# Fold 5
# Correct: 116 / 121
# microF1=0.9587 macroF1=0.9550
# Confusion matrix:
#  [[43  0  0  1  0]
#  [ 0  6  0  0  0]
#  [ 0  0 15  1  1]
#  [ 0  0  1 22  0]
#  [ 0  0  1  0 30]]
#
# ===== Gradient Boost CV Summary =====
# Mean micro-F1: 0.9572144695840672
# Mean macro-F1: 0.9495949584478165

# %%
# Run Hybrid Inference on ONE test page
# =============================================================================

model.eval()

# Pick one test page
test_source = list(test_sources)[0]
page_df = test_df[test_df["source"] == test_source].copy()
page_df = page_df.sort_values("rendering_order").reset_index(drop=True)

print("Running inference on page:", test_source)
print("Nodes:", len(page_df))

# -------------------------
# 1) Build dataset + loader for this single page
# -------------------------
num_mean = cv_results[0]["num_mean"]   # or use global stats
num_std  = cv_results[0]["num_std"]

single_dataset = PageDataset(page_df, tokenizer, num_mean, num_std)
single_loader = DataLoader(
    single_dataset,
    batch_size=1,
    shuffle=False,
    collate_fn=collate_fn
)

# -------------------------
# 2) Boundary prediction
# -------------------------
pages = collect_page_probs_and_truth(single_loader, model, device)

prob_B, true_start = pages[0]

pred_starts = pick_starts_from_probs(
    prob_B,
    threshold=best_th_cv,
    nms_k=1,
    min_gap=2
)

print("\nPredicted start indices:", pred_starts)

true_starts = np.where(true_start == 1)[0].tolist()

print("\n===== Boundary Verification =====")
print("True start indices :", true_starts)
print("Pred start indices :", pred_starts)

p, r, f1 = start_prf_with_tolerance(true_starts, pred_starts, tol=1)
print(f"P={p:.4f} R={r:.4f} F1={f1:.4f}")


print("\n===== Probability Around True Starts =====")
for idx in true_starts:
    lo = max(0, idx-2)
    hi = min(len(prob_B), idx+3)
    print(f"\nWindow around true start {idx}:")
    for i in range(lo, hi):
        print(f"Index {i:3d} | Prob_B={prob_B[i]:.3f}")

print("\n===== Full Boundary Table =====")
for i, row in page_df.iterrows():
    marker = ""
    if i in true_starts:
        marker += " [TRUE_START]"
    if i in pred_starts:
        marker += " [PRED_START]"
    print(f"{i:3d} | Prob={prob_B[i]:.3f} | {row['text_context'][:50]}{marker}")

# -------------------------
# 3) Convert starts -> event spans
# -------------------------
events = []
for i, start in enumerate(pred_starts):
    end = pred_starts[i+1] if i+1 < len(pred_starts) else len(page_df)
    events.append((start, end))

print("Predicted event spans:", events)

# -------------------------
# 4) Run Gradient Boost for each node inside events
# -------------------------

def build_features_for_nodes(df_subset):

    # ------------------
    # TEXT
    # ------------------
    X_text = tfidf.transform(df_subset["text_context"].astype(str))

    # ------------------
    # NUMERIC (force float32)
    # ------------------
    num_feats = (
        df_subset[STRUCT_COLS_NUM]
        .fillna(0)
        .astype("float32")
        .values
    )

    # ------------------
    # BOOL (force float32)
    # ------------------
    bool_feats = (
        df_subset[STRUCT_COLS_BOOL]
        .fillna(0)
        .astype("float32")
        .values
    )

    # ------------------
    # TAG ONE-HOT (aligned + float32)
    # ------------------
    tag_onehot = pd.get_dummies(df_subset["tag"].astype(str))
    tag_onehot = tag_onehot.reindex(columns=TAG_COLUMNS, fill_value=0)
    tag_onehot = tag_onehot.astype("float32").values

    # ------------------
    # PARENT TAG ONE-HOT (aligned + float32)
    # ------------------
    parent_onehot = pd.get_dummies(df_subset["parent_tag"].astype(str))
    parent_onehot = parent_onehot.reindex(columns=PARENT_COLUMNS, fill_value=0)
    parent_onehot = parent_onehot.astype("float32").values

    # ------------------
    # Combine
    # ------------------
    X_struct = np.hstack([
        num_feats,
        bool_feats,
        tag_onehot,
        parent_onehot
    ]).astype("float32")

    from scipy.sparse import csr_matrix, hstack

    X_struct = csr_matrix(X_struct)

    return hstack([X_text, X_struct])


print("\n========== FINAL OUTPUT ==========")

for e_idx, (start, end) in enumerate(events, 1):

    event_nodes = page_df.iloc[start:end].copy()
    X_nodes = build_features_for_nodes(event_nodes)

    y_pred = clf.predict(X_nodes)
    labels = le.inverse_transform(y_pred)

    print(f"\n--- Event {e_idx} ---")
    for i, row in event_nodes.iterrows():
        print(f"[{i}] TEXT: {row['text_context']}")
        print("    Predicted Field:", labels[i - start])
        print("    True Label:", row["label"])
# Out:
# Running inference on page: nacacnet.org_pattern_labeled
# Nodes: 547
#
# Predicted start indices: [416, 421, 429, 432, 436, 440, 444, 448, 452, 456, 460, 464, 468, 472, 476, 480, 485, 488, 492]
#
# ===== Boundary Verification =====
# True start indices : [412, 416, 420, 424, 428, 432, 436, 440, 444, 448, 452, 456, 460, 464, 468, 472, 476, 480, 484, 488, 492, 496]
# Pred start indices : [416, 421, 429, 432, 436, 440, 444, 448, 452, 456, 460, 464, 468, 472, 476, 480, 485, 488, 492]
# P=1.0000 R=0.8636 F1=0.9268
#
# ===== Probability Around True Starts =====
#
# Window around true start 412:
# Index 410 | Prob_B=0.082
# Index 411 | Prob_B=0.019
# Index 412 | Prob_B=0.106
# Index 413 | Prob_B=0.067
# Index 414 | Prob_B=0.091
#
# Window around true start 416:
# Index 414 | Prob_B=0.091
# Index 415 | Prob_B=0.023
# Index 416 | Prob_B=0.170
# Index 417 | Prob_B=0.071
# Index 418 | Prob_B=0.074
#
# Window around true start 420:
# Index 418 | Prob_B=0.074
# Index 419 | Prob_B=0.027
# Index 420 | Prob_B=0.089
# Index 421 | Prob_B=0.126
# Index 422 | Prob_B=0.091
#
# Window around true start 424:
# Index 422 | Prob_B=0.091
# Index 423 | Prob_B=0.018
# Index 424 | Prob_B=0.104
# Index 425 | Prob_B=0.087
# Index 426 | Prob_B=0.086
#
# Window around true start 428:
# Index 426 | Prob_B=0.086
# Index 427 | Prob_B=0.022
# Index 428 | Prob_B=0.150
# Index 429 | Prob_B=0.175
# Index 430 | Prob_B=0.044
#
# Window around true start 432:
# Index 430 | Prob_B=0.044
# Index 431 | Prob_B=0.020
# Index 432 | Prob_B=0.144
# Index 433 | Prob_B=0.070
# Index 434 | Prob_B=0.106
#
# Window around true start 436:
# Index 434 | Prob_B=0.106
# Index 435 | Prob_B=0.024
# Index 436 | Prob_B=0.136
# Index 437 | Prob_B=0.085
# Index 438 | Prob_B=0.054
#
# Window around true start 440:
# Index 438 | Prob_B=0.054
# Index 439 | Prob_B=0.021
# Index 440 | Prob_B=0.274
# Index 441 | Prob_B=0.144
# Index 442 | Prob_B=0.085
#
# Window around true start 444:
# Index 442 | Prob_B=0.085
# Index 443 | Prob_B=0.022
# Index 444 | Prob_B=0.270
# Index 445 | Prob_B=0.139
# Index 446 | Prob_B=0.060
#
# Window around true start 448:
# Index 446 | Prob_B=0.060
# Index 447 | Prob_B=0.025
# Index 448 | Prob_B=0.160
# Index 449 | Prob_B=0.097
# Index 450 | Prob_B=0.188
#
# Window around true start 452:
# Index 450 | Prob_B=0.188
# Index 451 | Prob_B=0.022
# Index 452 | Prob_B=0.250
# Index 453 | Prob_B=0.158
# Index 454 | Prob_B=0.104
#
# Window around true start 456:
# Index 454 | Prob_B=0.104
# Index 455 | Prob_B=0.022
# Index 456 | Prob_B=0.261
# Index 457 | Prob_B=0.125
# Index 458 | Prob_B=0.088
#
# Window around true start 460:
# Index 458 | Prob_B=0.088
# Index 459 | Prob_B=0.026
# Index 460 | Prob_B=0.158
# Index 461 | Prob_B=0.071
# Index 462 | Prob_B=0.089
#
# Window around true start 464:
# Index 462 | Prob_B=0.089
# Index 463 | Prob_B=0.023
# Index 464 | Prob_B=0.143
# Index 465 | Prob_B=0.080
# Index 466 | Prob_B=0.039
#
# Window around true start 468:
# Index 466 | Prob_B=0.039
# Index 467 | Prob_B=0.021
# Index 468 | Prob_B=0.160
# Index 469 | Prob_B=0.061
# Index 470 | Prob_B=0.055
#
# Window around true start 472:
# Index 470 | Prob_B=0.055
# Index 471 | Prob_B=0.022
# Index 472 | Prob_B=0.270
# Index 473 | Prob_B=0.097
# Index 474 | Prob_B=0.055
#
# Window around true start 476:
# Index 474 | Prob_B=0.055
# Index 475 | Prob_B=0.025
# Index 476 | Prob_B=0.166
# Index 477 | Prob_B=0.051
# Index 478 | Prob_B=0.036
#
# Window around true start 480:
# Index 478 | Prob_B=0.036
# Index 479 | Prob_B=0.024
# Index 480 | Prob_B=0.269
# Index 481 | Prob_B=0.146
# Index 482 | Prob_B=0.073
#
# Window around true start 484:
# Index 482 | Prob_B=0.073
# Index 483 | Prob_B=0.028
# Index 484 | Prob_B=0.156
# Index 485 | Prob_B=0.180
# Index 486 | Prob_B=0.097
#
# Window around true start 488:
# Index 486 | Prob_B=0.097
# Index 487 | Prob_B=0.025
# Index 488 | Prob_B=0.149
# Index 489 | Prob_B=0.081
# Index 490 | Prob_B=0.078
#
# Window around true start 492:
# Index 490 | Prob_B=0.078
# Index 491 | Prob_B=0.022
# Index 492 | Prob_B=0.125
# Index 493 | Prob_B=0.048
# Index 494 | Prob_B=0.042
#
# Window around true start 496:
# Index 494 | Prob_B=0.042
# Index 495 | Prob_B=0.018
# Index 496 | Prob_B=0.001
# Index 497 | Prob_B=0.000
# Index 498 | Prob_B=0.001
#
# ===== Full Boundary Table =====
#   0 | Prob=0.001 | for screen-reader mode - click the first button of
#   1 | Prob=0.001 | accessibility screen-reader guide, feedback, and i
#   2 | Prob=0.001 | skip to content
#   3 | Prob=0.002 | search for:
#   4 | Prob=0.001 | toggle navigation
#   5 | Prob=0.000 | who we are
#   6 | Prob=0.001 | who we are
#   7 | Prob=0.005 | learn about our history, meet the staff and the bo
#   8 | Prob=0.001 | explore who we are
#   9 | Prob=0.000 | mission & vision
#  10 | Prob=0.000 | what we do
#  11 | Prob=0.001 | nacac history
#  12 | Prob=0.000 | meet the team
#  13 | Prob=0.000 | volunteer leaders
#  14 | Prob=0.000 | affiliates
#  15 | Prob=0.000 | guiding ethics
#  16 | Prob=0.000 | impact report
#  17 | Prob=0.000 | membership
#  18 | Prob=0.001 | membership
#  19 | Prob=0.001 | a nacac membership unlocks best in class opportuni
#  20 | Prob=0.001 | explore membership
#  21 | Prob=0.000 | member resources
#  22 | Prob=0.000 | what to know before you apply
#  23 | Prob=0.000 | maximize your member benefits
#  24 | Prob=0.000 | membership categories and pricing
#  25 | Prob=0.000 | member demographics
#  26 | Prob=0.000 | international membership
#  27 | Prob=0.002 | join nacac
#  28 | Prob=0.000 | renew your membership
#  29 | Prob=0.000 | events
#  30 | Prob=0.001 | events
#  31 | Prob=0.001 | nacac offers its members myriad opportunities to l
#  32 | Prob=0.001 | explore the calendar
#  33 | Prob=0.000 | annual conference
#  34 | Prob=0.000 | upcoming webinars
#  35 | Prob=0.000 | guiding the way to impact
#  36 | Prob=0.001 | nacac college fairs
#  37 | Prob=0.000 | – attend a college fair
#  38 | Prob=0.001 | – exhibit at a nacac college fair
#  39 | Prob=0.000 | – sponsor a nacac college fair
#  40 | Prob=0.000 | affiliate annual conferences
#  41 | Prob=0.000 | resources
#  42 | Prob=0.001 | resources
#  43 | Prob=0.001 | nacac's wide variety of research and reports, publ
#  44 | Prob=0.001 | explore resources
#  45 | Prob=0.000 | for counseling professionals
#  46 | Prob=0.000 | for admission professionals
#  47 | Prob=0.000 | for students and families
#  48 | Prob=0.001 | center for innovation in college admission
#  49 | Prob=0.001 | diversity, equity, and inclusion
#  50 | Prob=0.000 | research and reports
#  51 | Prob=0.000 | fundamentals of college admission counseling
#  52 | Prob=0.001 | newsroom
#  53 | Prob=0.000 | education
#  54 | Prob=0.001 | education
#  55 | Prob=0.002 | nacac offers professional development in the form
#  56 | Prob=0.001 | explore education
#  57 | Prob=0.000 | certificate programs
#  58 | Prob=0.000 | on-demand learning
#  59 | Prob=0.000 | webinars
#  60 | Prob=0.000 | virtual forums
#  61 | Prob=0.000 | industry insights
#  62 | Prob=0.000 | sponsorship opportunities
#  63 | Prob=0.000 | guiding the way to impact
#  64 | Prob=0.000 | nacac’s character focus initiative
#  65 | Prob=0.000 | access your courses & proof of completion
#  66 | Prob=0.000 | advocacy
#  67 | Prob=0.001 | advocacy
#  68 | Prob=0.002 | as the voice of the college admission counseling p
#  69 | Prob=0.001 | explore what we stand for
#  70 | Prob=0.000 | nacac advocacy in action
#  71 | Prob=0.000 | nacac advocacy toolkit
#  72 | Prob=0.001 | the supreme court and race-conscious admission
#  73 | Prob=0.001 | student and equity centered college admission
#  74 | Prob=0.000 | support for school counselors
#  75 | Prob=0.000 | college access and affordability
#  76 | Prob=0.000 | guiding ethics
#  77 | Prob=0.000 | donate to nacac
#  78 | Prob=0.000 | get involved
#  79 | Prob=0.001 | get involved
#  80 | Prob=0.001 | there are many ways for non-members to help nacac.
#  81 | Prob=0.001 | learn more
#  82 | Prob=0.000 | volunteer
#  83 | Prob=0.000 | sponsorship & advertising opportunities
#  84 | Prob=0.000 | special interest groups (sigs)
#  85 | Prob=0.000 | sig calendar
#  86 | Prob=0.001 | exhibit at a nacac college fair
#  87 | Prob=0.000 | donate to nacac
#  88 | Prob=0.002 | search for:
#  89 | Prob=0.001 | toggle navigation
#  90 | Prob=0.000 | who we are
#  91 | Prob=0.000 | mission & vision
#  92 | Prob=0.000 | what we do
#  93 | Prob=0.000 | nacac history
#  94 | Prob=0.000 | meet the team
#  95 | Prob=0.000 | nacac volunteer leaders
#  96 | Prob=0.000 | affiliates
#  97 | Prob=0.000 | guiding ethics
#  98 | Prob=0.000 | impact report
#  99 | Prob=0.000 | membership
# 100 | Prob=0.000 | member resources
# 101 | Prob=0.000 | what to know before you apply
# 102 | Prob=0.000 | maximize your member benefits
# 103 | Prob=0.000 | membership categories and pricing
# 104 | Prob=0.000 | member demographics
# 105 | Prob=0.000 | international membership
# 106 | Prob=0.001 | join nacac
# 107 | Prob=0.000 | events
# 108 | Prob=0.000 | annual conference
# 109 | Prob=0.000 | upcoming webinars
# 110 | Prob=0.000 | guiding the way to impact
# 111 | Prob=0.000 | nacac college fairs
# 112 | Prob=0.000 | affiliate annual conferences
# 113 | Prob=0.000 | resources
# 114 | Prob=0.000 | for counseling professionals
# 115 | Prob=0.000 | for admission professionals
# 116 | Prob=0.000 | for students and families
# 117 | Prob=0.001 | center for innovation in college admission
# 118 | Prob=0.001 | diversity, equity, and inclusion
# 119 | Prob=0.000 | research and reports
# 120 | Prob=0.000 | fundamentals of college admission counseling
# 121 | Prob=0.001 | newsroom
# 122 | Prob=0.007 | career center
# 123 | Prob=0.000 | nacac engage
# 124 | Prob=0.000 | education
# 125 | Prob=0.000 | certificate programs
# 126 | Prob=0.000 | on-demand learning
# 127 | Prob=0.000 | webinars
# 128 | Prob=0.000 | virtual forums
# 129 | Prob=0.000 | industry insights
# 130 | Prob=0.000 | sponsorship opportunities
# 131 | Prob=0.000 | guiding the way to inclusion
# 132 | Prob=0.000 | nacac’s character focus initiative
# 133 | Prob=0.000 | access your courses & proof of completion
# 134 | Prob=0.000 | advocacy
# 135 | Prob=0.000 | nacac advocacy in action
# 136 | Prob=0.000 | nacac advocacy toolkit
# 137 | Prob=0.000 | the supreme court and race-conscious admission
# 138 | Prob=0.000 | student and equity centered college admission
# 139 | Prob=0.000 | support for school counselors
# 140 | Prob=0.000 | college access and affordability
# 141 | Prob=0.000 | guiding ethics
# 142 | Prob=0.000 | donate
# 143 | Prob=0.000 | get involved
# 144 | Prob=0.000 | volunteer
# 145 | Prob=0.000 | donate
# 146 | Prob=0.000 | sponsorship & advertising opportunities
# 147 | Prob=0.000 | special interest groups
# 148 | Prob=0.000 | – sig calendar
# 149 | Prob=0.001 | exhibit at a nacac college fair
# 150 | Prob=0.000 | donate
# 151 | Prob=0.000 | store
# 152 | Prob=0.006 | career center
# 153 | Prob=0.000 | contact us
# 154 | Prob=0.000 | professional
# 155 | Prob=0.000 | student
# 156 | Prob=0.001 | nacac account login
# 157 | Prob=0.000 | professional
# 158 | Prob=0.000 | student
# 159 | Prob=0.001 | toggle navigation
# 160 | Prob=0.000 | join
# 161 | Prob=0.000 | donate
# 162 | Prob=0.000 | nacac engage
# 163 | Prob=0.000 | nacac learn
# 164 | Prob=0.000 | store
# 165 | Prob=0.006 | career center
# 166 | Prob=0.000 | contact us
# 167 | Prob=0.002 | search for:
# 168 | Prob=0.001 | toggle navigation
# 169 | Prob=0.000 | who we are
# 170 | Prob=0.001 | who we are
# 171 | Prob=0.005 | learn about our history, meet the staff and the bo
# 172 | Prob=0.001 | explore who we are
# 173 | Prob=0.000 | mission & vision
# 174 | Prob=0.000 | what we do
# 175 | Prob=0.001 | nacac history
# 176 | Prob=0.000 | meet the team
# 177 | Prob=0.000 | volunteer leaders
# 178 | Prob=0.000 | affiliates
# 179 | Prob=0.000 | guiding ethics
# 180 | Prob=0.000 | impact report
# 181 | Prob=0.000 | membership
# 182 | Prob=0.001 | membership
# 183 | Prob=0.001 | a nacac membership unlocks best in class opportuni
# 184 | Prob=0.001 | explore membership
# 185 | Prob=0.000 | member resources
# 186 | Prob=0.000 | what to know before you apply
# 187 | Prob=0.000 | maximize your member benefits
# 188 | Prob=0.000 | membership categories and pricing
# 189 | Prob=0.000 | member demographics
# 190 | Prob=0.000 | international membership
# 191 | Prob=0.002 | join nacac
# 192 | Prob=0.000 | renew your membership
# 193 | Prob=0.000 | events
# 194 | Prob=0.001 | events
# 195 | Prob=0.001 | nacac offers its members myriad opportunities to l
# 196 | Prob=0.001 | explore the calendar
# 197 | Prob=0.000 | annual conference
# 198 | Prob=0.000 | upcoming webinars
# 199 | Prob=0.000 | guiding the way to impact
# 200 | Prob=0.001 | nacac college fairs
# 201 | Prob=0.000 | – attend a college fair
# 202 | Prob=0.001 | – exhibit at a nacac college fair
# 203 | Prob=0.000 | – sponsor a nacac college fair
# 204 | Prob=0.000 | affiliate annual conferences
# 205 | Prob=0.000 | resources
# 206 | Prob=0.001 | resources
# 207 | Prob=0.001 | nacac's wide variety of research and reports, publ
# 208 | Prob=0.001 | explore resources
# 209 | Prob=0.000 | for counseling professionals
# 210 | Prob=0.000 | for admission professionals
# 211 | Prob=0.000 | for students and families
# 212 | Prob=0.001 | center for innovation in college admission
# 213 | Prob=0.001 | diversity, equity, and inclusion
# 214 | Prob=0.000 | research and reports
# 215 | Prob=0.000 | fundamentals of college admission counseling
# 216 | Prob=0.001 | newsroom
# 217 | Prob=0.000 | education
# 218 | Prob=0.001 | education
# 219 | Prob=0.002 | nacac offers professional development in the form
# 220 | Prob=0.001 | explore education
# 221 | Prob=0.000 | certificate programs
# 222 | Prob=0.000 | on-demand learning
# 223 | Prob=0.000 | webinars
# 224 | Prob=0.000 | virtual forums
# 225 | Prob=0.000 | industry insights
# 226 | Prob=0.000 | sponsorship opportunities
# 227 | Prob=0.000 | guiding the way to impact
# 228 | Prob=0.000 | nacac’s character focus initiative
# 229 | Prob=0.000 | access your courses & proof of completion
# 230 | Prob=0.000 | advocacy
# 231 | Prob=0.001 | advocacy
# 232 | Prob=0.002 | as the voice of the college admission counseling p
# 233 | Prob=0.001 | explore what we stand for
# 234 | Prob=0.000 | nacac advocacy in action
# 235 | Prob=0.000 | nacac advocacy toolkit
# 236 | Prob=0.001 | the supreme court and race-conscious admission
# 237 | Prob=0.001 | student and equity centered college admission
# 238 | Prob=0.000 | support for school counselors
# 239 | Prob=0.000 | college access and affordability
# 240 | Prob=0.000 | guiding ethics
# 241 | Prob=0.000 | donate to nacac
# 242 | Prob=0.000 | get involved
# 243 | Prob=0.001 | get involved
# 244 | Prob=0.001 | there are many ways for non-members to help nacac.
# 245 | Prob=0.001 | learn more
# 246 | Prob=0.000 | volunteer
# 247 | Prob=0.000 | sponsorship & advertising opportunities
# 248 | Prob=0.000 | special interest groups (sigs)
# 249 | Prob=0.000 | sig calendar
# 250 | Prob=0.001 | exhibit at a nacac college fair
# 251 | Prob=0.000 | donate to nacac
# 252 | Prob=0.002 | search for:
# 253 | Prob=0.002 | search for:
# 254 | Prob=0.001 | toggle navigation
# 255 | Prob=0.000 | who we are
# 256 | Prob=0.001 | who we are
# 257 | Prob=0.004 | learn about our history, meet the staff and the bo
# 258 | Prob=0.001 | explore who we are
# 259 | Prob=0.000 | mission & vision
# 260 | Prob=0.000 | what we do
# 261 | Prob=0.001 | nacac history
# 262 | Prob=0.000 | meet the team
# 263 | Prob=0.000 | volunteer leaders
# 264 | Prob=0.000 | affiliates
# 265 | Prob=0.000 | guiding ethics
# 266 | Prob=0.000 | impact report
# 267 | Prob=0.000 | membership
# 268 | Prob=0.001 | membership
# 269 | Prob=0.001 | a nacac membership unlocks best in class opportuni
# 270 | Prob=0.001 | explore membership
# 271 | Prob=0.000 | member resources
# 272 | Prob=0.000 | what to know before you apply
# 273 | Prob=0.000 | maximize your member benefits
# 274 | Prob=0.000 | membership categories and pricing
# 275 | Prob=0.000 | member demographics
# 276 | Prob=0.000 | international membership
# 277 | Prob=0.001 | join nacac
# 278 | Prob=0.000 | renew your membership
# 279 | Prob=0.000 | events
# 280 | Prob=0.001 | events
# 281 | Prob=0.001 | nacac offers its members myriad opportunities to l
# 282 | Prob=0.001 | explore the calendar
# 283 | Prob=0.000 | annual conference
# 284 | Prob=0.000 | upcoming webinars
# 285 | Prob=0.000 | guiding the way to impact
# 286 | Prob=0.001 | nacac college fairs
# 287 | Prob=0.000 | – attend a college fair
# 288 | Prob=0.000 | – exhibit at a nacac college fair
# 289 | Prob=0.000 | – sponsor a nacac college fair
# 290 | Prob=0.000 | affiliate annual conferences
# 291 | Prob=0.000 | resources
# 292 | Prob=0.001 | resources
# 293 | Prob=0.001 | nacac's wide variety of research and reports, publ
# 294 | Prob=0.001 | explore resources
# 295 | Prob=0.000 | for counseling professionals
# 296 | Prob=0.000 | for admission professionals
# 297 | Prob=0.000 | for students and families
# 298 | Prob=0.001 | center for innovation in college admission
# 299 | Prob=0.001 | diversity, equity, and inclusion
# 300 | Prob=0.000 | research and reports
# 301 | Prob=0.000 | fundamentals of college admission counseling
# 302 | Prob=0.001 | newsroom
# 303 | Prob=0.000 | education
# 304 | Prob=0.001 | education
# 305 | Prob=0.002 | nacac offers professional development in the form
# 306 | Prob=0.001 | explore education
# 307 | Prob=0.000 | certificate programs
# 308 | Prob=0.000 | on-demand learning
# 309 | Prob=0.000 | webinars
# 310 | Prob=0.000 | virtual forums
# 311 | Prob=0.000 | industry insights
# 312 | Prob=0.000 | sponsorship opportunities
# 313 | Prob=0.000 | guiding the way to impact
# 314 | Prob=0.000 | nacac’s character focus initiative
# 315 | Prob=0.000 | access your courses & proof of completion
# 316 | Prob=0.000 | advocacy
# 317 | Prob=0.001 | advocacy
# 318 | Prob=0.002 | as the voice of the college admission counseling p
# 319 | Prob=0.001 | explore what we stand for
# 320 | Prob=0.000 | nacac advocacy in action
# 321 | Prob=0.000 | nacac advocacy toolkit
# 322 | Prob=0.001 | the supreme court and race-conscious admission
# 323 | Prob=0.001 | student and equity centered college admission
# 324 | Prob=0.000 | support for school counselors
# 325 | Prob=0.000 | college access and affordability
# 326 | Prob=0.000 | guiding ethics
# 327 | Prob=0.000 | donate to nacac
# 328 | Prob=0.000 | get involved
# 329 | Prob=0.001 | get involved
# 330 | Prob=0.001 | there are many ways for non-members to help nacac.
# 331 | Prob=0.001 | learn more
# 332 | Prob=0.000 | volunteer
# 333 | Prob=0.000 | sponsorship & advertising opportunities
# 334 | Prob=0.000 | special interest groups (sigs)
# 335 | Prob=0.000 | sig calendar
# 336 | Prob=0.001 | exhibit at a nacac college fair
# 337 | Prob=0.000 | donate to nacac
# 338 | Prob=0.002 | search for:
# 339 | Prob=0.005 | exhibit at a nacac college fair
# 340 | Prob=0.001 | jp
# 341 | Prob=0.029 | 2026-01-23t15:24:57-05:00
# 342 | Prob=0.004 | exhibit at a nacac college fair
# 343 | Prob=0.003 | » »
# 344 | Prob=0.001 | home
# 345 | Prob=0.001 | get involved
# 346 | Prob=0.002 | exhibit at a nacac college fair
# 347 | Prob=0.009 | due to the inclement weather expected in atlanta,
# 348 | Prob=0.001 | ×
# 349 | Prob=0.002 | exhibitor registration for spring 2026 college fai
# 350 | Prob=0.000 | book a booth
# 351 | Prob=0.002 | exhibit at a nacac national college fair
# 352 | Prob=0.000 | terms, policies, and pricing
# 353 | Prob=0.000 | cancellations and refunds
# 354 | Prob=0.000 | exhibitor guidelines
# 355 | Prob=0.001 | exhibitor guidelines for stem college and career f
# 356 | Prob=0.000 | exhibitor faqs
# 357 | Prob=0.000 | matchmaking regions
# 358 | Prob=0.000 | in-person lead retrieval
# 359 | Prob=0.000 | in-person national college fair fee waiver program
# 360 | Prob=0.000 | gap year programs
# 361 | Prob=0.000 | health and safety policy
# 362 | Prob=0.000 | exhibit at a virtual college fair
# 363 | Prob=0.000 | virtual exhibitor faqs
# 364 | Prob=0.002 | exhibit at nacac college fairs to connect with tho
# 365 | Prob=0.000 | terms, policies, and pricing
# 366 | Prob=0.000 | cancellations and refunds
# 367 | Prob=0.000 | exhibitor guidelines
# 368 | Prob=0.001 | exhibitor guidelines for stem college and career f
# 369 | Prob=0.000 | exhibitor faqs
# 370 | Prob=0.000 | matchmaking regions
# 371 | Prob=0.000 | in-person lead retrieval
# 372 | Prob=0.000 | in-person national college fair fee waiver program
# 373 | Prob=0.000 | gap year programs
# 374 | Prob=0.000 | health and safety policy
# 375 | Prob=0.000 | exhibit at a virtual college fair
# 376 | Prob=0.000 | virtual exhibitor faqs
# 377 | Prob=0.004 | 0
# 378 | Prob=0.001 | in-person and virtual fairs coming in spring 2026
# 379 | Prob=0.004 | 0
# 380 | Prob=0.003 | k+
# 381 | Prob=0.001 | students reached per year
# 382 | Prob=0.004 | 0
# 383 | Prob=0.002 | +
# 384 | Prob=0.001 | colleges and universities
# 385 | Prob=0.001 | exhibitor fees – spring 2026
# 386 | Prob=0.001 | national college fairs
# 387 | Prob=0.001 | nacac members
# 388 | Prob=0.001 | non-members
# 389 | Prob=0.058 | early bird rate (until dec. 18)
# 390 | Prob=0.025 | $770
# 391 | Prob=0.021 | $990
# 392 | Prob=0.099 | regular rate (after dec. 18)
# 393 | Prob=0.043 | $825
# 394 | Prob=0.052 | $1,045
# 395 | Prob=0.001 | *rates for the new york city and boston national c
# 396 | Prob=0.002 | stem college fairs
# 397 | Prob=0.001 | category
# 398 | Prob=0.013 | nacac member institution
# 399 | Prob=0.031 | $550
# 400 | Prob=0.025 | nonmember institution
# 401 | Prob=0.038 | $600
# 402 | Prob=0.000 | please note that fees for stem college and career
# 403 | Prob=0.001 | search:
# 404 | Prob=0.003 | fair date(s)
# 405 | Prob=0.001 | location
# 406 | Prob=0.002 | venue
# 407 | Prob=0.001 | time
# 408 | Prob=0.106 | jan. 25, 2026
# 409 | Prob=0.069 | cleveland - postponed
# 410 | Prob=0.082 | huntington convention center of cleveland
# 411 | Prob=0.019 | 1/25: 1 p.m.-4 p.m.
# 412 | Prob=0.106 | jan. 25, 2026 [TRUE_START]
# 413 | Prob=0.067 | atlanta - postponed
# 414 | Prob=0.091 | georgia international convention center
# 415 | Prob=0.023 | 1/25: 11:00 a.m.-2:30 p.m.
# 416 | Prob=0.170 | jan. 27-28, 2026 [TRUE_START] [PRED_START]
# 417 | Prob=0.071 | pittsburgh - postponed
# 418 | Prob=0.074 | david l. lawrence convention center
# 419 | Prob=0.027 | 1/27: 9 a.m.-noon, 6 p.m.-8:30 p.m. 1/28: 9 a.m.-n
# 420 | Prob=0.089 | feb. 7, 2026 [TRUE_START]
# 421 | Prob=0.126 | greater columbus [PRED_START]
# 422 | Prob=0.091 | greater columbus convention center
# 423 | Prob=0.018 | 2/7: 1 p.m.-4 p.m.
# 424 | Prob=0.104 | feb. 10, 2026 [TRUE_START]
# 425 | Prob=0.087 | greater los angeles
# 426 | Prob=0.086 | pasedena convention center
# 427 | Prob=0.022 | 2/10: 9 a.m.-12:30 p.m., 5:30 p.m.-8 p.m.
# 428 | Prob=0.150 | march 1, 2026 [TRUE_START]
# 429 | Prob=0.175 | miami [PRED_START]
# 430 | Prob=0.044 | miami airport convention center (adjacent to the d
# 431 | Prob=0.020 | 3/1: noon-4 p.m.
# 432 | Prob=0.144 | march 4, 2026 [TRUE_START] [PRED_START]
# 433 | Prob=0.070 | new jersey
# 434 | Prob=0.106 | new jersey convention and exposition center
# 435 | Prob=0.024 | 3/4: 9 a.m.-noon, 5:30 p.m.-8:30 p.m.
# 436 | Prob=0.136 | march 5, 2026 [TRUE_START] [PRED_START]
# 437 | Prob=0.085 | austin
# 438 | Prob=0.054 | palmer events center
# 439 | Prob=0.021 | 3/5: 6 p.m.-8:30 p.m.
# 440 | Prob=0.274 | march 15-16, 2026 [TRUE_START] [PRED_START]
# 441 | Prob=0.144 | rochester
# 442 | Prob=0.085 | rochester riverside convention center
# 443 | Prob=0.022 | 3/15: 1 p.m.-3 p.m. 3/16: 9 a.m.-11:30 a.m.
# 444 | Prob=0.270 | march 16-17, 2026 [TRUE_START] [PRED_START]
# 445 | Prob=0.139 | syracuse
# 446 | Prob=0.060 | the oncenter convention center
# 447 | Prob=0.025 | 3/16: 5 p.m.-7:30 p.m. 3/17: 9 a.m.-11:30 a.m.
# 448 | Prob=0.160 | march 17, 2026 [TRUE_START] [PRED_START]
# 449 | Prob=0.097 | springfield
# 450 | Prob=0.188 | eastern states exposition
# 451 | Prob=0.022 | 3/17: 9 a.m.-11:30 a.m.
# 452 | Prob=0.250 | march 17-18, 2025 [TRUE_START] [PRED_START]
# 453 | Prob=0.158 | hartford
# 454 | Prob=0.104 | connecticut convention center
# 455 | Prob=0.022 | 3/17: 5:30 p.m.-8 p.m. 3/18: 9 a.m.-1 p.m.
# 456 | Prob=0.261 | march 18-19, 2026 [TRUE_START] [PRED_START]
# 457 | Prob=0.125 | buffalo
# 458 | Prob=0.088 | buffalo convention center
# 459 | Prob=0.026 | 3/18: 9 a.m.-noon, 6 p.m.-8:00 p.m. 3/19: 9 a.m.-n
# 460 | Prob=0.158 | march 21, 2026 [TRUE_START] [PRED_START]
# 461 | Prob=0.071 | charlotte
# 462 | Prob=0.089 | charlotte convention center
# 463 | Prob=0.023 | 3/21: noon-3 p.m.
# 464 | Prob=0.143 | april 2, 2026 [TRUE_START] [PRED_START]
# 465 | Prob=0.080 | houston
# 466 | Prob=0.039 | nrg center
# 467 | Prob=0.021 | 4/2: 9:30 a.m.-12:30 p.m., 6 p.m.-8 p.m.
# 468 | Prob=0.160 | april 19, 2026 [TRUE_START] [PRED_START]
# 469 | Prob=0.061 | new york city
# 470 | Prob=0.055 | jacob k. javits convention center
# 471 | Prob=0.022 | 4/19: noon-4 p.m.
# 472 | Prob=0.270 | april 21-22, 2026 [TRUE_START] [PRED_START]
# 473 | Prob=0.097 | montgomery county
# 474 | Prob=0.055 | adventist healthcare fieldhouse
# 475 | Prob=0.025 | 4/21: 9:45 a.m.-1 p.m., 6:30 p.m.-8 p.m. 4/22: 9:4
# 476 | Prob=0.166 | april 24, 2026 [TRUE_START] [PRED_START]
# 477 | Prob=0.051 | prince george's county
# 478 | Prob=0.036 | prince george's sports and learning complex
# 479 | Prob=0.024 | 4/24: 9:30 a.m.-12:30 p.m.
# 480 | Prob=0.269 | april 27-28, 2026 [TRUE_START] [PRED_START]
# 481 | Prob=0.146 | boston
# 482 | Prob=0.073 | hynes convention center
# 483 | Prob=0.028 | 4/27: 5:30 p.m.-8:30 p.m. 4/28: 8:30 a.m.-12:30 p.
# 484 | Prob=0.156 | april 29, 2026 [TRUE_START]
# 485 | Prob=0.180 | providence [PRED_START]
# 486 | Prob=0.097 | rhode island convention center
# 487 | Prob=0.025 | 4/29: 5:30 p.m.-7:30 p.m.
# 488 | Prob=0.149 | april 30, 2026 [TRUE_START] [PRED_START]
# 489 | Prob=0.081 | metro detroit
# 490 | Prob=0.078 | suburban collection showplace
# 491 | Prob=0.022 | 4/30: 8:30 a.m.-11:30 a.m., 6 p.m.-8 p.m.
# 492 | Prob=0.125 | june 6, 2026 [TRUE_START] [PRED_START]
# 493 | Prob=0.048 | denver stem
# 494 | Prob=0.042 | colorado school of mines
# 495 | Prob=0.018 | 6/6: 1 p.m.-4 p.m.
# 496 | Prob=0.001 | spring 2026 college fairs schedule graphic [TRUE_START]
# 497 | Prob=0.000 | also available as a pdf
# 498 | Prob=0.001 | click or tap to enlarge
# 499 | Prob=0.001 | exhibitor information
# 500 | Prob=0.007 | nacac national college fair – austin exhibitor inf
# 501 | Prob=0.005 | nacac national college fair – boston exhibitor inf
# 502 | Prob=0.008 | nacac national college fair – buffalo exhibitor in
# 503 | Prob=0.010 | nacac national college fair – charlotte exhibitor
# 504 | Prob=0.009 | nacac national college fair – columbus exhibitor i
# 505 | Prob=0.009 | nacac national college fair – greater los angeles
# 506 | Prob=0.010 | nacac national college fair – hartford exhibitor i
# 507 | Prob=0.007 | nacac national college fair – houston exhibitor in
# 508 | Prob=0.009 | nacac national college fair – metro detroit exhibi
# 509 | Prob=0.005 | 1
# 510 | Prob=0.002 | 2
# 511 | Prob=0.000 | next
# 512 | Prob=0.001 | about nacac
# 513 | Prob=0.002 | the national association for college admission cou
# 514 | Prob=0.002 | our bylaws
# 515 | Prob=0.001 | professional
# 516 | Prob=0.001 | for counseling professionals
# 517 | Prob=0.001 | for admission professionals
# 518 | Prob=0.001 | student
# 519 | Prob=0.001 | student tools
# 520 | Prob=0.001 | college fairs
# 521 | Prob=0.001 | nonprofit status
# 522 | Prob=0.001 | the internal revenue service recognizes the nation
# 523 | Prob=0.002 | | |
# 524 | Prob=0.001 | privacy policy
# 525 | Prob=0.001 | cookie policy
# 526 | Prob=0.002 | payment policy
# 527 | Prob=0.001 | contact us
# 528 | Prob=0.016 | 1050 north highland street suite 400 arlington, va
# 529 | Prob=0.000 | national association for college admission counsel
# 530 | Prob=0.002 | 800-822-6285
# 531 | Prob=0.001 | info@nacacnet.org
# 532 | Prob=0.000 | © copyright 2026 | all rights reserved | nacac
# 533 | Prob=0.001 | page load link
# 534 | Prob=0.001 | important notice
# 535 | Prob=0.001 | nacac host hotels will not reach out to you direct
# 536 | Prob=0.000 | nacac does not share your contact information with
# 537 | Prob=0.001 | collegefairs@nacacnet.org
# 538 | Prob=0.002 | cookies on the nacac website we use cookies to giv
# 539 | Prob=0.001 | privacy
# 540 | Prob=0.001 | cookies and similar technologies
# 541 | Prob=0.001 | accept
# 542 | Prob=0.001 | decline
# 543 | Prob=0.001 | <iframe src=https://www.googletagmanager.com/ns.ht
# 544 | Prob=0.000 | go to top
# 545 | Prob=0.000 | notifications
# 546 | Prob=0.001 | <img height="1" width="1" style="display:none" src
# Predicted event spans: [(416, 421), (421, 429), (429, 432), (432, 436), (436, 440), (440, 444), (444, 448), (448, 452), (452, 456), (456, 460), (460, 464), (464, 468), (468, 472), (472, 476), (476, 480), (480, 485), (485, 488), (488, 492), (492, 547)]
#
# ========== FINAL OUTPUT ==========
#
# --- Event 1 ---
# [416] TEXT: jan. 27-28, 2026
#     Predicted Field: Date
#     True Label: Date
# [417] TEXT: pittsburgh - postponed
#     Predicted Field: Location
#     True Label: Location
# [418] TEXT: david l. lawrence convention center
#     Predicted Field: Location
#     True Label: Location
# [419] TEXT: 1/27: 9 a.m.-noon, 6 p.m.-8:30 p.m. 1/28: 9 a.m.-noon
#     Predicted Field: Time
#     True Label: Time
# [420] TEXT: feb. 7, 2026
#     Predicted Field: Date
#     True Label: Date
#
# --- Event 2 ---
# [421] TEXT: greater columbus
#     Predicted Field: Location
#     True Label: Location
# [422] TEXT: greater columbus convention center
#     Predicted Field: Location
#     True Label: Location
# [423] TEXT: 2/7: 1 p.m.-4 p.m.
#     Predicted Field: Time
#     True Label: Time
# [424] TEXT: feb. 10, 2026
#     Predicted Field: Date
#     True Label: Date
# [425] TEXT: greater los angeles
#     Predicted Field: Location
#     True Label: Location
# [426] TEXT: pasedena convention center
#     Predicted Field: Location
#     True Label: Location
# [427] TEXT: 2/10: 9 a.m.-12:30 p.m., 5:30 p.m.-8 p.m.
#     Predicted Field: Time
#     True Label: Time
# [428] TEXT: march 1, 2026
#     Predicted Field: Date
#     True Label: Date
#
# --- Event 3 ---
# [429] TEXT: miami
#     Predicted Field: Location
#     True Label: Location
# [430] TEXT: miami airport convention center (adjacent to the doubletree by hilton miami)
#     Predicted Field: Location
#     True Label: Location
# [431] TEXT: 3/1: noon-4 p.m.
#     Predicted Field: Time
#     True Label: Time
#
# --- Event 4 ---
# [432] TEXT: march 4, 2026
#     Predicted Field: Date
#     True Label: Date
# [433] TEXT: new jersey
#     Predicted Field: Location
#     True Label: Location
# [434] TEXT: new jersey convention and exposition center
#     Predicted Field: Location
#     True Label: Location
# [435] TEXT: 3/4: 9 a.m.-noon, 5:30 p.m.-8:30 p.m.
#     Predicted Field: Time
#     True Label: Time
#
# --- Event 5 ---
# [436] TEXT: march 5, 2026
#     Predicted Field: Date
#     True Label: Date
# [437] TEXT: austin
#     Predicted Field: Location
#     True Label: Location
# [438] TEXT: palmer events center
#     Predicted Field: Location
#     True Label: Location
# [439] TEXT: 3/5: 6 p.m.-8:30 p.m.
#     Predicted Field: Time
#     True Label: Time
#
# --- Event 6 ---
# [440] TEXT: march 15-16, 2026
#     Predicted Field: Date
#     True Label: Date
# [441] TEXT: rochester
#     Predicted Field: Location
#     True Label: Location
# [442] TEXT: rochester riverside convention center
#     Predicted Field: Location
#     True Label: Location
# [443] TEXT: 3/15: 1 p.m.-3 p.m. 3/16: 9 a.m.-11:30 a.m.
#     Predicted Field: Time
#     True Label: Time
#
# --- Event 7 ---
# [444] TEXT: march 16-17, 2026
#     Predicted Field: Date
#     True Label: Date
# [445] TEXT: syracuse
#     Predicted Field: Location
#     True Label: Location
# [446] TEXT: the oncenter convention center
#     Predicted Field: Location
#     True Label: Location
# [447] TEXT: 3/16: 5 p.m.-7:30 p.m. 3/17: 9 a.m.-11:30 a.m.
#     Predicted Field: Time
#     True Label: Time
#
# --- Event 8 ---
# [448] TEXT: march 17, 2026
#     Predicted Field: Date
#     True Label: Date
# [449] TEXT: springfield
#     Predicted Field: Location
#     True Label: Location
# [450] TEXT: eastern states exposition
#     Predicted Field: Location
#     True Label: Location
# [451] TEXT: 3/17: 9 a.m.-11:30 a.m.
#     Predicted Field: Time
#     True Label: Time
#
# --- Event 9 ---
# [452] TEXT: march 17-18, 2025
#     Predicted Field: Date
#     True Label: Date
# [453] TEXT: hartford
#     Predicted Field: Location
#     True Label: Location
# [454] TEXT: connecticut convention center
#     Predicted Field: Location
#     True Label: Location
# [455] TEXT: 3/17: 5:30 p.m.-8 p.m. 3/18: 9 a.m.-1 p.m.
#     Predicted Field: Time
#     True Label: Time
#
# --- Event 10 ---
# [456] TEXT: march 18-19, 2026
#     Predicted Field: Date
#     True Label: Date
# [457] TEXT: buffalo
#     Predicted Field: Location
#     True Label: Location
# [458] TEXT: buffalo convention center
#     Predicted Field: Location
#     True Label: Location
# [459] TEXT: 3/18: 9 a.m.-noon, 6 p.m.-8:00 p.m. 3/19: 9 a.m.-noon
#     Predicted Field: Time
#     True Label: Time
#
# --- Event 11 ---
# [460] TEXT: march 21, 2026
#     Predicted Field: Date
#     True Label: Date
# [461] TEXT: charlotte
#     Predicted Field: Location
#     True Label: Location
# [462] TEXT: charlotte convention center
#     Predicted Field: Location
#     True Label: Location
# [463] TEXT: 3/21: noon-3 p.m.
#     Predicted Field: Time
#     True Label: Time
#
# --- Event 12 ---
# [464] TEXT: april 2, 2026
#     Predicted Field: Date
#     True Label: Date
# [465] TEXT: houston
#     Predicted Field: Location
#     True Label: Location
# [466] TEXT: nrg center
#     Predicted Field: Location
#     True Label: Location
# [467] TEXT: 4/2: 9:30 a.m.-12:30 p.m., 6 p.m.-8 p.m.
#     Predicted Field: Time
#     True Label: Time
#
# --- Event 13 ---
# [468] TEXT: april 19, 2026
#     Predicted Field: Date
#     True Label: Date
# [469] TEXT: new york city
#     Predicted Field: Location
#     True Label: Location
# [470] TEXT: jacob k. javits convention center
#     Predicted Field: Location
#     True Label: Location
# [471] TEXT: 4/19: noon-4 p.m.
#     Predicted Field: Time
#     True Label: Time
#
# --- Event 14 ---
# [472] TEXT: april 21-22, 2026
#     Predicted Field: Date
#     True Label: Date
# [473] TEXT: montgomery county
#     Predicted Field: Location
#     True Label: Location
# [474] TEXT: adventist healthcare fieldhouse
#     Predicted Field: Location
#     True Label: Location
# [475] TEXT: 4/21: 9:45 a.m.-1 p.m., 6:30 p.m.-8 p.m. 4/22: 9:45 a.m.-1 p.m.
#     Predicted Field: Time
#     True Label: Time
#
# --- Event 15 ---
# [476] TEXT: april 24, 2026
#     Predicted Field: Date
#     True Label: Date
# [477] TEXT: prince george's county
#     Predicted Field: Location
#     True Label: Location
# [478] TEXT: prince george's sports and learning complex
#     Predicted Field: Location
#     True Label: Location
# [479] TEXT: 4/24: 9:30 a.m.-12:30 p.m.
#     Predicted Field: Time
#     True Label: Time
#
# --- Event 16 ---
# [480] TEXT: april 27-28, 2026
#     Predicted Field: Date
#     True Label: Date
# [481] TEXT: boston
#     Predicted Field: Location
#     True Label: Location
# [482] TEXT: hynes convention center
#     Predicted Field: Location
#     True Label: Location
# [483] TEXT: 4/27: 5:30 p.m.-8:30 p.m. 4/28: 8:30 a.m.-12:30 p.m.
#     Predicted Field: Time
#     True Label: Time
# [484] TEXT: april 29, 2026
#     Predicted Field: Date
#     True Label: Date
#
# --- Event 17 ---
# [485] TEXT: providence
#     Predicted Field: Location
#     True Label: Location
# [486] TEXT: rhode island convention center
#     Predicted Field: Location
#     True Label: Location
# [487] TEXT: 4/29: 5:30 p.m.-7:30 p.m.
#     Predicted Field: Time
#     True Label: Time
#
# --- Event 18 ---
# [488] TEXT: april 30, 2026
#     Predicted Field: Date
#     True Label: Date
# [489] TEXT: metro detroit
#     Predicted Field: Location
#     True Label: Location
# [490] TEXT: suburban collection showplace
#     Predicted Field: Location
#     True Label: Location
# [491] TEXT: 4/30: 8:30 a.m.-11:30 a.m., 6 p.m.-8 p.m.
#     Predicted Field: Time
#     True Label: Time
#
# --- Event 19 ---
# [492] TEXT: june 6, 2026
#     Predicted Field: Date
#     True Label: Date
# [493] TEXT: denver stem
#     Predicted Field: Location
#     True Label: Location
# [494] TEXT: colorado school of mines
#     Predicted Field: Location
#     True Label: Location
# [495] TEXT: 6/6: 1 p.m.-4 p.m.
#     Predicted Field: Time
#     True Label: Time
# [496] TEXT: spring 2026 college fairs schedule graphic
#     Predicted Field: Name
#     True Label: Date
# [497] TEXT: also available as a pdf
#     Predicted Field: Location
#     True Label: Location
# [498] TEXT: click or tap to enlarge
#     Predicted Field: Location
#     True Label: Location
# [499] TEXT: exhibitor information
#     Predicted Field: Time
#     True Label: Time
# [500] TEXT: nacac national college fair – austin exhibitor info
#     Predicted Field: Name
#     True Label: Other
# [501] TEXT: nacac national college fair – boston exhibitor info
#     Predicted Field: Name
#     True Label: Other
# [502] TEXT: nacac national college fair – buffalo exhibitor info
#     Predicted Field: Name
#     True Label: Other
# [503] TEXT: nacac national college fair – charlotte exhibitor info
#     Predicted Field: Name
#     True Label: Other
# [504] TEXT: nacac national college fair – columbus exhibitor info
#     Predicted Field: Name
#     True Label: Other
# [505] TEXT: nacac national college fair – greater los angeles exhibitor info
#     Predicted Field: Name
#     True Label: Other
# [506] TEXT: nacac national college fair – hartford exhibitor info
#     Predicted Field: Name
#     True Label: Other
# [507] TEXT: nacac national college fair – houston exhibitor info
#     Predicted Field: Name
#     True Label: Other
# [508] TEXT: nacac national college fair – metro detroit exhibitor info
#     Predicted Field: Name
#     True Label: Other
# [509] TEXT: 1
#     Predicted Field: Date
#     True Label: Other
# [510] TEXT: 2
#     Predicted Field: Date
#     True Label: Other
# [511] TEXT: next
#     Predicted Field: Name
#     True Label: Other
# [512] TEXT: about nacac
#     Predicted Field: Location
#     True Label: Other
# [513] TEXT: the national association for college admission counseling (nacac), founded in 1937, is an organization of more than 28,000 professionals from around the world dedicated to serving students as they make choices about pursuing postsecondary education.
#     Predicted Field: Description
#     True Label: Other
# [514] TEXT: our bylaws
#     Predicted Field: Location
#     True Label: Other
# [515] TEXT: professional
#     Predicted Field: Location
#     True Label: Other
# [516] TEXT: for counseling professionals
#     Predicted Field: Location
#     True Label: Other
# [517] TEXT: for admission professionals
#     Predicted Field: Location
#     True Label: Other
# [518] TEXT: student
#     Predicted Field: Date
#     True Label: Other
# [519] TEXT: student tools
#     Predicted Field: Location
#     True Label: Other
# [520] TEXT: college fairs
#     Predicted Field: Location
#     True Label: Other
# [521] TEXT: nonprofit status
#     Predicted Field: Location
#     True Label: Other
# [522] TEXT: the internal revenue service recognizes the national association for college admission counseling inc as a 501(c)(3) exempt organization and public charity. nacac’s tax identification number is ein: 26-1909449
#     Predicted Field: Description
#     True Label: Other
# [523] TEXT: | |
#     Predicted Field: Location
#     True Label: Other
# [524] TEXT: privacy policy
#     Predicted Field: Name
#     True Label: Other
# [525] TEXT: cookie policy
#     Predicted Field: Name
#     True Label: Other
# [526] TEXT: payment policy
#     Predicted Field: Location
#     True Label: Other
# [527] TEXT: contact us
#     Predicted Field: Location
#     True Label: Other
# [528] TEXT: 1050 north highland street suite 400 arlington, va 22201
#     Predicted Field: Location
#     True Label: Other
# [529] TEXT: national association for college admission counseling
#     Predicted Field: Location
#     True Label: Other
# [530] TEXT: 800-822-6285
#     Predicted Field: Date
#     True Label: Other
# [531] TEXT: info@nacacnet.org
#     Predicted Field: Name
#     True Label: Other
# [532] TEXT: © copyright 2026 | all rights reserved | nacac
#     Predicted Field: Location
#     True Label: Other
# [533] TEXT: page load link
#     Predicted Field: Location
#     True Label: Other
# [534] TEXT: important notice
#     Predicted Field: Location
#     True Label: Other
# [535] TEXT: nacac host hotels will not reach out to you directly for payment or registration details. if you are contacted by someone claiming to be with a hotel, do not provide them with any personal or financial information. please contact if you have any questions.
#     Predicted Field: Description
#     True Label: Other
# [536] TEXT: nacac does not share your contact information with our contracted host hotels.
#     Predicted Field: Location
#     True Label: Other
# [537] TEXT: collegefairs@nacacnet.org
#     Predicted Field: Location
#     True Label: Other
# [538] TEXT: cookies on the nacac website we use cookies to give you the best digital experiences while visiting our websites. by visiting our sites, you agree to our updated and terms of use and policies.
#     Predicted Field: Description
#     True Label: Other
# [539] TEXT: privacy
#     Predicted Field: Location
#     True Label: Other
# [540] TEXT: cookies and similar technologies
#     Predicted Field: Location
#     True Label: Other
# [541] TEXT: accept
#     Predicted Field: Date
#     True Label: Other
# [542] TEXT: decline
#     Predicted Field: Date
#     True Label: Other
# [543] TEXT: <iframe src=https://www.googletagmanager.com/ns.html?id=gtm-wq2q88g height="0" width="0" style="display:none;visibility:hidden"></iframe>
#     Predicted Field: Description
#     True Label: Other
# [544] TEXT: go to top
#     Predicted Field: Name
#     True Label: Other
# [545] TEXT: notifications
#     Predicted Field: Location
#     True Label: Other
# [546] TEXT: <img height="1" width="1" style="display:none" src="https://www.facebook.com/tr?id=337244911710996&amp;ev=pageview&amp;noscript=1">
#     Predicted Field: Time
#     True Label: Other
